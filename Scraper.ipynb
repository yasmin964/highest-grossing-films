# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import re
# from database import load_films_to_db

# Base URL for Wikipedia
BASE_URL = "https://en.wikipedia.org"
HEADERS = {'User-Agent': 'Mozilla/5.0'}

def get_films_soup():
    """
    Fetch the Wikipedia page containing the list of highest-grossing films
    and return its parsed BeautifulSoup object.
    """
    response = requests.get(BASE_URL + '/wiki/List_of_highest-grossing_films', headers=HEADERS)
    return BeautifulSoup(response.content, "lxml")

soup = get_films_soup()

def extract(title_link):
    """
    Extracts key information from a given film's Wikipedia page.
    
    Parameters:
        title_link (str): The URL of the film's Wikipedia page.
    
    Returns:
        dict: A dictionary containing relevant film details.
    """
    response = requests.get(title_link, headers=HEADERS)
    if response.status_code != 200:
        return {}

    soup = BeautifulSoup(response.content, 'html.parser')
    infobox = soup.find("table", {"class": "infobox vevent"})

    if not infobox:
        return {}

    data = {}
    for row in infobox.find_all("tr"):
        header = row.find("th")
        value = row.find("td")

        if header and value:
            key = header.text.strip()
            val = value.text.strip()

            # Normalize field names and values
            if key in ["Directed by", "Produced by", "Box office", "Country", "Countries"]:
                if key in ["Directed by", "Produced by"]:
                    val = ', '.join(val.split('\n'))  # Separate names with commas
                if key in ["Country", "Countries"]:
                    key = "Country"  # Standardizing the key
                data[key] = val

    return data

def clean_text(text):
    """
    Cleans the extracted text by removing unwanted characters, extra spaces, and formatting inconsistencies.
    
    Parameters:
        text (str): The raw extracted text.
    
    Returns:
        str: The cleaned text.
    """
    if text is None:
        return ''
    text = re.sub(r'\[.*?\]', '', text)  # Remove reference brackets
    text = text.replace('\xa0billion', '').replace('billion', '').replace('\n', ' ')
    text = re.sub(r'[^0-9.]', '', text) if text.replace('.', '').isdigit() else text  # Keep only digits for box office values
    return text.strip()

# Locate the table containing the list of films
table = soup.find('table', {'class': 'wikitable'})
films_data = []

# Extract relevant information from each row
for row in table.find_all('tr')[1:]:  # Skipping header row
    columns = row.find_all(["th", "td"])
    if len(columns) < 5:
        continue

    title = columns[2].text.strip()
    year = columns[4].text.strip()

    title_link = columns[2].find("a")
    link = urljoin(BASE_URL, title_link["href"]) if title_link else None

    add_info = extract(link) if link else {}

    film = {
        "title": title,
        "year": year,
        **add_info
    }
    films_data.append(film)

# Clean the extracted data
cleaned_films = []
for film in films_data:
    cleaned_film = {key: clean_text(value) for key, value in film.items()}
    cleaned_films.append(cleaned_film)

# Print extracted films
for film in cleaned_films:
    print(film)
# Out:
# {'title': 'Avatar', 'year': '2009', 'Directed by': 'James Cameron', 'Produced by': 'James Cameron, Jon Landau', 'Country': 'United Kingdom United States', 'Box office': '$2.923'}
# {'title': 'Avengers: Endgame', 'year': '2019', 'Directed by': 'Anthony RussoJoe Russo', 'Produced by': 'Kevin Feige', 'Country': 'United States', 'Box office': '$2.799'}
# {'title': 'Avatar: The Way of Water', 'year': '2022', 'Directed by': 'James Cameron', 'Produced by': 'James Cameron, Jon Landau', 'Country': 'United States', 'Box office': '$2.320'}
# {'title': 'Titanic', 'year': '1997', 'Directed by': 'James Cameron', 'Produced by': 'James Cameron, Jon Landau', 'Country': 'United States', 'Box office': '$2.264'}
# {'title': 'Star Wars: The Force Awakens', 'year': '2015', 'Directed by': 'J. J. Abrams', 'Produced by': 'Kathleen Kennedy, J. J. Abrams, Bryan Burk', 'Country': 'United States', 'Box office': '$2.07'}
# {'title': 'Avengers: Infinity War', 'year': '2018', 'Directed by': 'Anthony RussoJoe Russo', 'Produced by': 'Kevin Feige', 'Country': 'United States', 'Box office': '$2.052'}
# {'title': 'Spider-Man: No Way Home', 'year': '2021', 'Directed by': 'Jon Watts', 'Produced by': 'Kevin Feige, Amy Pascal', 'Country': 'United States', 'Box office': '$1.953'}
# {'title': 'Ne Zha 2 †', 'year': '2025', 'Directed by': 'Jiaozi', 'Produced by': 'Liu Wenzhang, Wang Jing', 'Country': 'China', 'Box office': 'US$1.88'}
# {'title': 'Inside Out 2', 'year': '2024', 'Directed by': 'Kelsey Mann', 'Produced by': 'Mark Nielsen', 'Country': 'United States', 'Box office': '$1.699'}
# {'title': 'Jurassic World', 'year': '2015', 'Directed by': 'Colin Trevorrow', 'Produced by': 'Frank Marshall, Patrick Crowley', 'Country': 'United States', 'Box office': '$1.671'}
# {'title': 'The Lion King', 'year': '2019', 'Directed by': 'Jon Favreau', 'Produced by': 'Jon Favreau, Jeffrey Silver, Karen Gilchrist', 'Country': 'United States', 'Box office': '$1.657'}
# {'title': 'The Avengers', 'year': '2012', 'Directed by': 'Joss Whedon', 'Produced by': 'Kevin Feige', 'Country': 'United States', 'Box office': '$1.521'}
# {'title': 'Furious 7', 'year': '2015', 'Directed by': 'James Wan', 'Produced by': 'Neal H. Moritz, Vin Diesel, Michael Fottrell', 'Country': 'United States China', 'Box office': '$1.515'}
# {'title': 'Top Gun: Maverick', 'year': '2022', 'Directed by': 'Joseph Kosinski', 'Produced by': 'Jerry Bruckheimer, Tom Cruise, Christopher McQuarrie, David Ellison', 'Country': 'United States', 'Box office': '$1.496'}
# {'title': 'Frozen 2', 'year': '2019', 'Directed by': 'Chris Buck, Jennifer Lee', 'Produced by': 'Peter Del Vecho', 'Country': 'United States', 'Box office': '$1.453'}
# {'title': 'Barbie', 'year': '2023', 'Directed by': 'Greta Gerwig', 'Produced by': 'David Heyman, Margot Robbie, Tom Ackerley, Robbie Brenner', 'Country': 'United States United Kingdom', 'Box office': '$1.446'}
# {'title': 'Avengers: Age of Ultron', 'year': '2015', 'Directed by': 'Joss Whedon', 'Produced by': 'Kevin Feige', 'Country': 'United States', 'Box office': '$1.405'}
# {'title': 'The Super Mario Bros. Movie', 'year': '2023', 'Directed by': 'Aaron Horvath, Michael Jelenic', 'Produced by': 'Chris Meledandri, Shigeru Miyamoto', 'Country': 'United States', 'Box office': '$1.360'}
# {'title': 'Black Panther', 'year': '2018', 'Directed by': 'Ryan Coogler', 'Produced by': 'Kevin Feige', 'Country': 'United States', 'Box office': '$1.35'}
# {'title': 'Harry Potter and the Deathly Hallows – Part 2', 'year': '2011', 'Directed by': 'David Yates', 'Produced by': 'David Heyman, David Barron, J. K. Rowling', 'Country': 'United Kingdom United States', 'Box office': '$1.342'}
# {'title': 'Deadpool & Wolverine', 'year': '2024', 'Directed by': 'Shawn Levy', 'Produced by': 'Kevin Feige, Lauren Shuler Donner, Ryan Reynolds, Shawn Levy', 'Country': 'United States', 'Box office': '$1.338'}
# {'title': 'Star Wars: The Last Jedi', 'year': '2017', 'Directed by': 'Rian Johnson', 'Produced by': 'Kathleen Kennedy, Ram Bergman', 'Country': 'United States', 'Box office': '$1.334'}
# {'title': 'Jurassic World: Fallen Kingdom', 'year': '2018', 'Directed by': 'J. A. Bayona', 'Produced by': 'Frank Marshall, Patrick Crowley, Belén Atienza', 'Country': 'China United States', 'Box office': '$1.31'}
# {'title': 'Frozen', 'year': '2013', 'Directed by': 'Chris Buck, Jennifer Lee', 'Produced by': 'Peter Del Vecho', 'Country': 'United States', 'Box office': '$1.280'}
# {'title': 'Beauty and the Beast', 'year': '2017', 'Directed by': 'Bill Condon', 'Produced by': 'David Hoberman, Todd Lieberman', 'Country': 'United States', 'Box office': '$1.266'}
# {'title': 'Incredibles 2', 'year': '2018', 'Directed by': 'Brad Bird', 'Produced by': 'John Walker, Nicole Paradis Grindle', 'Country': 'United States', 'Box office': '$1.243'}
# {'title': 'The Fate of the Furious', 'year': '2017', 'Directed by': 'F. Gary Gray', 'Produced by': 'Neal H. Moritz, Vin Diesel, Michael Fottrell, Chris Morgan', 'Country': 'United States China', 'Box office': '$1.236'}
# {'title': 'Iron Man 3', 'year': '2013', 'Directed by': 'Shane Black', 'Produced by': 'Kevin Feige', 'Country': 'United States', 'Box office': '$1.266'}
# {'title': 'Minions', 'year': '2015', 'Directed by': 'Pierre Coffin, Kyle Balda', 'Produced by': 'Chris Meledandri, Janet Healy', 'Country': 'United States', 'Box office': '$1.159'}
# {'title': 'Captain America: Civil War', 'year': '2016', 'Directed by': 'Anthony RussoJoe Russo', 'Produced by': 'Kevin Feige', 'Country': 'United States', 'Box office': '$1.155'}
# {'title': 'Aquaman', 'year': '2018', 'Directed by': 'James Wan', 'Produced by': 'Peter Safran, Rob Cowan', 'Country': 'United States', 'Box office': '$1.152'}
# {'title': 'The Lord of the Rings: The Return of the King', 'year': '2003', 'Directed by': 'Peter Jackson', 'Produced by': 'Barrie M. Osborne, Fran Walsh, Peter Jackson', 'Country': 'New Zealand Germany United States', 'Box office': '$1.151'}
# {'title': 'Spider-Man: Far From Home', 'year': '2019', 'Directed by': 'Jon Watts', 'Produced by': 'Kevin Feige, Amy Pascal', 'Country': 'United States', 'Box office': '$1.133'}
# {'title': 'Captain Marvel', 'year': '2019', 'Directed by': 'Anna BodenRyan Fleck', 'Produced by': 'Kevin Feige', 'Country': 'United States', 'Box office': '$1.131'}
# {'title': 'Transformers: Dark of the Moon', 'year': '2011', 'Directed by': 'Michael Bay', 'Produced by': 'Lorenzo di Bonaventura, Tom DeSanto, Don Murphy, Ian Bryce', 'Country': 'United States', 'Box office': '$1.124'}
# {'title': 'Skyfall', 'year': '2012', 'Directed by': 'Sam Mendes', 'Produced by': 'Michael G. Wilson, Barbara Broccoli', 'Country': 'United KingdomUnited States', 'Box office': '$1.109'}
# {'title': 'Transformers: Age of Extinction', 'year': '2014', 'Directed by': 'Michael Bay', 'Produced by': 'Lorenzo di Bonaventura, Tom DeSanto, Don Murphy, Ian Bryce', 'Country': 'United States', 'Box office': '$1.104'}
# {'title': 'The Dark Knight Rises', 'year': '2012', 'Directed by': 'Christopher Nolan', 'Produced by': 'Emma Thomas, Christopher Nolan, Charles Roven', 'Country': 'United States United Kingdom', 'Box office': '$1.115'}
# {'title': 'Joker', 'year': '2019', 'Directed by': 'Todd Phillips', 'Produced by': 'Todd Phillips, Bradley Cooper, Emma Tillinger Koskoff', 'Country': 'United States', 'Box office': '$1.079'}
# {'title': 'Star Wars: The Rise of Skywalker', 'year': '2019', 'Directed by': 'J. J. Abrams', 'Produced by': 'Kathleen Kennedy, J. J. Abrams, Michelle Rejwan', 'Country': 'United States', 'Box office': '$1.077'}
# {'title': 'Toy Story 4', 'year': '2019', 'Directed by': 'Josh Cooley', 'Produced by': 'Mark Nielsen, Jonas Rivera', 'Country': 'United States', 'Box office': '$1.074'}
# {'title': 'Toy Story 3', 'year': '2010', 'Directed by': 'Lee Unkrich', 'Produced by': 'Darla K. Anderson', 'Country': 'United States', 'Box office': '$1.067'}
# {'title': "Pirates of the Caribbean: Dead Man's Chest", 'year': '2006', 'Directed by': 'Gore Verbinski', 'Produced by': 'Jerry Bruckheimer', 'Country': 'United States', 'Box office': '$1.066'}
# {'title': 'Rogue One: A Star Wars Story', 'year': '2016', 'Directed by': 'Gareth Edwards', 'Produced by': 'Kathleen Kennedy, Allison Shearmur, Simon Emanuel', 'Country': 'United States', 'Box office': '$1.059'}
# {'title': 'Moana 2 †', 'year': '2024', 'Directed by': 'David Derrick Jr., Jason Hand, Dana Ledoux Miller', 'Produced by': 'Christina Chen, Yvett Merino', 'Country': 'United States', 'Box office': '$1.05'}
# {'title': 'Aladdin', 'year': '2019', 'Directed by': 'Guy Ritchie', 'Produced by': 'Dan Lin, Jonathan Eirich', 'Country': 'United States', 'Box office': '$1.054'}
# {'title': 'Star Wars: Episode I – The Phantom Menace', 'year': '1999', 'Directed by': 'George Lucas', 'Produced by': 'Rick McCallum', 'Country': 'United States', 'Box office': '$1.047'}
# {'title': 'Pirates of the Caribbean: On Stranger Tides', 'year': '2011', 'Directed by': 'Rob Marshall', 'Produced by': 'Jerry Bruckheimer', 'Country': 'United States', 'Box office': '$1.046'}
# {'title': 'Jurassic Park', 'year': '1993', 'Directed by': 'Steven Spielberg', 'Produced by': 'Kathleen Kennedy, Gerald R. Molen', 'Country': 'United States', 'Box office': '$1.058'}
# {'title': 'Despicable Me 3', 'year': '2017', 'Directed by': 'Pierre Coffin, Kyle Balda', 'Produced by': 'Chris Meledandri, Janet Healy', 'Country': 'United States', 'Box office': '$1.035'}

# %%
import sqlite3

# Database file name
DB_FILE = "films.db"

def create_table():
    """
    Creates the 'films' table in the SQLite database if it does not already exist.
    """
    conn = sqlite3.connect(DB_FILE)
    cursor = conn.cursor()

    cursor.execute("""
    CREATE TABLE IF NOT EXISTS films (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        title TEXT NOT NULL,
        release_year INTEGER,
        director TEXT,
        producers TEXT,
        box_office TEXT,
        country TEXT
    );
    """)

    conn.commit()
    conn.close()

def load_films_to_db(films):
    """
    Loads a list of films into the SQLite database.
    
    Parameters:
        films (list): A list of dictionaries containing film details.
    """
    conn = sqlite3.connect(DB_FILE)
    cursor = conn.cursor()

    for film in films:
        cursor.execute("""
        INSERT INTO films (title, release_year, director, producers, box_office, country)
        VALUES (?, ?, ?, ?, ?, ?)
        """, (
            # Safely get values, even if the key is missing
            film.get("title", ""),
            film.get("year", None),
            film.get("Directed by", ""),
            film.get("Produced by", ""),
            film.get("Box office", ""),
            film.get("Country", "")
        ))

    # Commit all inserted records
    conn.commit()
    conn.close()

load_films_to_db(cleaned_films)
# Create the table before loading data
create_table()
